# %% [markdown]
# 1. [Title](#Best-holidays-ever)

# %% [markdown]
# # Best holidays ever

# %% [markdown]
# #### <font color = "green"> The purpose of this notebook is to show an amaizing dog live and practice the Markdown cheat sheet! </font>

# %%
friend = input("Please enter the name of your best friend in the world :")

# %% [markdown]
# # ![Kin_Amsterdam1.jpg](attachment:Kin_Amsterdam1.jpg)

# %% [markdown]
# #### I would like to know your *favorite destination* for holidays.

# %%
holidays = input("Could you tell me what are your favorite destinations for holidays?\n")

# %% [markdown]
# ![Kin2.jpeg](attachment:Kin2.jpeg)

# %% [markdown]
# Here my **top 3 things** that I like to do at this destination

# %% [markdown]
# - Sleep
# - Eat
# - Try to hunt a mosquito

# %% [markdown]
# [Link to Cancun](https://youtu.be/Wf6K2Q7447E)
